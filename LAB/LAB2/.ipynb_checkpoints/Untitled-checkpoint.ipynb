# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = np.array([[2005],[2006],[2007],[2008],[2009]])
y = np.array([[12],[19],[29],[37],[45]])

# %%
regressionModel = LinearRegression()
regressionModel.fit(x,y)

y_predict = regressionModel.predict(x)

print(y_predict)
# Out:
# [[11.6]
#  [20. ]
#  [28.4]
#  [36.8]
#  [45.2]]

# %%
rmse = np.sqrt(mean_squared_error(y,y_predict))
r2 = r2_score(y,y_predict)
print (r2)
print('Slope',regressionModel.coef_)
print('Intercept',regressionModel.intercept_)
# Out:
# 0.9977375565610798
# Slope [[8.4]]
# Intercept [-16830.4]

# %%
print(y_predict)
plt.scatter(x,y,s=10)
# Out:
# [[11.6]
#  [20. ]
#  [28.4]
#  [36.8]
#  [45.2]]

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/paulmathai/python-virtual-enviorments/CSE4020/LAB/LAB2/data.csv')

# %%
data.plot(x='Year', y='Value', style='o')
plt.xlabel("Year")
plt.ylabel("Sales")
plt.show()
x = data.iloc(:,:-1).values
x = data.iloc(:,:1).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/keras_tf/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-60e1369ba710> in <module>()
# ...
